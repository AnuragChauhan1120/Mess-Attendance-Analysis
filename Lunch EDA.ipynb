# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("lunch_clean_updated.csv.xlsx")

# %%
df = df.replace({np.nan: None})
df
# Out:
#           Date        Day Weather Exam Week Special Event  Attendance
# 0   2025-01-15  Wednesday   Sunny        No       Holiday         169
# 1   2025-01-16   Thursday  Cloudy        No          None         193
# 2   2025-01-17     Friday  Cloudy        No        Sports         211
# 3   2025-01-18   Saturday   Sunny        No          None         198
# 4   2025-01-19     Sunday   Rainy        No          Tech         169
# ..         ...        ...     ...       ...           ...         ...
# 116 2025-05-11     Sunday   Sunny       Yes       Holiday         136
# 117 2025-05-12     Monday  Cloudy        No          None         194
# 118 2025-05-13    Tuesday  Cloudy        No          None         196
# 119 2025-05-14  Wednesday  Cloudy        No          Tech         207
# 120 2025-05-15   Thursday   Rainy        No          None         178
#
# [121 rows x 6 columns]

# %%
print("\nAttendance Stats:\n", df["Attendance"].describe())
# Out:
# Attendance Stats:
#  count    121.000000
# mean     187.462810
# std       24.233944
# min      127.000000
# 25%      169.000000
# 50%      190.000000
# 75%      206.000000
# max      233.000000
# Name: Attendance, dtype: float64

# %%
attendance_by_day = df.groupby("Day")["Attendance"].mean()
attendance_by_weather = df.groupby("Weather")["Attendance"].mean()
attendance_by_exam = df.groupby("Exam Week")["Attendance"].mean()
attendance_by_event = df.groupby("Special Event")["Attendance"].mean()

# %%
print(attendance_by_day)
# Out:
# Day
# Friday       196.000000
# Monday       190.647059
# Saturday     172.411765
# Sunday       172.117647
# Thursday     189.555556
# Tuesday      196.647059
# Wednesday    194.333333
# Name: Attendance, dtype: float64

# %%
print(attendance_by_weather)
# Out:
# Weather
# Cloudy    188.741935
# Rainy     163.269231
# Sunny     196.671875
# Name: Attendance, dtype: float64

# %%
print(attendance_by_exam)
# Out:
# Exam Week
# No     192.625
# Yes    167.640
# Name: Attendance, dtype: float64

# %%
print(attendance_by_event)
# Out:
# Special Event
# Cultural           197.750000
# Festival           162.857143
# Holiday            160.857143
# Movie Screening    179.666667
# Sports             176.250000
# Tech               198.000000
# Name: Attendance, dtype: float64

# %%
plt.figure(figsize=(14, 10))
plt.subplot(2, 2, 1)
attendance_by_day.plot(kind='bar', color='skyblue')
plt.title("Average Attendance by Day")
plt.ylabel("Attendance")
# Out:
# Text(0, 0.5, 'Attendance')

# %%
plt.subplot(2, 2, 3)
attendance_by_exam.plot(kind='bar', color='green')
plt.title("Average Attendance by Exam Week")
plt.ylabel("Attendance")
# Out:
# Text(0, 0.5, 'Attendance')

# %%
plt.subplot(2, 2, 4)
attendance_by_event.plot(kind='bar', color='purple')
plt.title("Average Attendance by Event")
plt.ylabel("Attendance")
# Out:
# Text(0, 0.5, 'Attendance')
